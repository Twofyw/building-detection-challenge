# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from learn import *

# %% [markdown]
# Train on full dataset for several epochs

# %%
# %%time
# %run script 1 --gpu_start=1 --num_gpus=1 --bs=32 --lr 1e-3 --num_slice=25 --rescale \
    --use_wd_sched --wd 0.025 --n_cycles 3 --model_name unet --learn --start
# Out:
# ...
# Data finished loading: data/train/AOI_3_Paris_Train
# ...
# epoch      trn_loss   val_loss   mask_acc   jaccard_coef_par
#     0      3.225907   1.881493   0.783799   0.181094
#     1      2.467047   1.837861   0.661727   0.220767
#     2      2.168024   1.575074   0.809077   0.245542
#     3      1.951717   1.405284   0.885215   0.228077
#     4      1.803075   1.318791   0.867445   0.257429
#     5      1.695874   1.295195   0.867385   0.263418
#     6      1.588304   0.986057   0.901074   0.356004
#     7      1.477353   1.007104   0.887335   0.352738
#     8      1.377753   0.906532   0.909822   0.390743
#     9      1.298969   0.884123   0.923569   0.390974
#     10     1.231138   0.871398   0.929805   0.394093
#     11     1.17589    0.849002   0.920944   0.410368
#     12     1.131044   0.836967   0.923446   0.415171
#     13     1.094298   0.83399    0.925019   0.415477
#
# CPU times: user 2h 25min 4s, sys: 4h 26min 45s, total: 6h 51min 49s
# Wall time: 17min 58s

# %%
# %%time
# %run script 1 --gpu_start=1 --num_gpus=1 --bs=32 --lr 1e-3 --num_slice=25 --rescale \
    --use_wd_sched --wd 0.025 --n_cycles 6 --model_name unet --learn --start
# Out:
# ...
# Data finished loading: data/train/AOI_3_Paris_Train
# ...
# epoch      trn_loss   val_loss   mask_acc   jaccard_coef_par
#     0      1.161147   0.977103   0.891382   0.362282
#     1      1.084186   0.876311   0.911084   0.397196
#     2      1.042875   0.9129     0.933848   0.372847
#     3      1.023097   0.904092   0.903057   0.397854
#     4      1.005593   0.843344   0.914625   0.414833
#     5      0.990568   0.823627   0.922169   0.419178
#     6      0.978008   0.866951   0.90923    0.410856
#     7      0.97882    0.827321   0.914609   0.421347
#     8      0.975684   0.783685   0.92683    0.435397
#     9      0.960409   0.78036    0.934827   0.435574
#     10     0.946151   0.790235   0.928139   0.435463
#     11     0.930486   0.777661   0.929125   0.440622
#     12     0.91837    0.769586   0.930921   0.443721
#     13     0.908609   0.766707   0.931701   0.444542
#     14     0.906566   0.839613   0.91252    0.425153
#     15     0.909449   0.795959   0.933753   0.425654
# ...

# %%
train_and_plot(learn, 1, 'unet-paris-rescale', lrs = lrs, n_cycles=6, wds=wds, use_wd_sched=use_wd_sched,
    cycle_len=1, cycle_mult=2, best_save_name='unet-paris-rescale')
# Out:
# ...
#   0%|          | 0/11 [00:00<?, ?it/s]
