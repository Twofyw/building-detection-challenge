# %% [markdown]
# # Deeplab

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from learn import *

# %%
sz = 256
num_slice = 25

num_gpus = 5
gpu_start = 1
num_workers = 8
device_ids = range(gpu_start, gpu_start + num_gpus)
torch.cuda.set_device(gpu_start)
bs = 7 * num_gpus

# %%
model_name = 'deeplab'

# %%
data = None

# %%
learn, denorm, data = learner_on_dataset(datapaths[3], bs, device_ids, num_workers, model_name='deeplab',
                                         debug=False, global_dataset=True, data=data, num_slice=num_slice, sz=sz)
(trn_x,trn_y), (val_x,val_y) = data
# Out:
# HBox(children=(IntProgress(value=0, description='ims', max=304), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='ims', max=708), HTML(value='')))
# Data finished loading: data/train/AOI_5_Khartoum_Train

# %%
learn.load('deeplab-5')
learn.unfreeze()

# %%
# %%time
lr = 1e-5 / 10
lrs = np.array([lr/9, lr])
wd = 0.010
wds = [wd/9, wd]
learn.unfreeze()
train_and_plot(learn, 1, 'deeplab-5', lrs=lrs, n_cycles=4, wds=wds, use_wd_sched=True,
               cycle_len=2, cycle_mult=2, best_save_name='deeplab-5')
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=30), HTML(value='')))
#  89%|████████▉ | 451/506 [11:12<01:22,  1.49s/it, loss=0.214]    1      0.210776   0.18171    0.160498
#     2      0.211278   0.17709    0.160498
#     3      0.216617   0.181554   0.160498
#     4      0.209678   0.180059   0.160498
#  19%|█▉        | 95/506 [02:19<10:05,  1.47s/it, loss=0.21]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#     9      0.217657   0.179766   0.160498
#     10     0.208065   0.177996   0.160498
#  96%|█████████▌| 487/506 [11:30<00:26,  1.42s/it, loss=0.21]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#     16     0.209061   0.177867   0.160498
#  94%|█████████▎| 474/506 [11:15<00:45,  1.43s/it, loss=0.213]    17     0.210578   0.175671   0.160498
# 100%|█████████▉| 505/506 [12:01<00:01,  1.43s/it, loss=0.208]    18     0.208191   0.179025   0.160498
#     19     0.208385   0.179023   0.160498
#     20     0.208571   0.178921   0.160498
#  95%|█████████▌| 481/506 [11:24<00:35,  1.42s/it, loss=0.211]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#     27     0.209985   0.17912    0.160498
#     28     0.21097    0.17809    0.160498
#     29     0.209838   0.175296   0.160498
#
# CPU times: user 1d 18h 20min 8s, sys: 1d 4h 50min 54s, total: 2d 23h 11min 3s
# Wall time: 6h 58min

# %%
learn.lr_find()
learn.sched.plot()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#   0%|          | 0/362 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-02ca863ce486> in <module>()
# ----> 1 learn.lr_find()
#       2 learn.sched.plot()
#
# ~/building-detection-challenge/fastai/learner.py in lr_find(self, start_lr, end_lr, wds, linear, **kwargs)
#     292         layer_opt = self.get_layer_opt(start_lr, wds)
#     293         self.sched = LR_Finder(layer_opt, len(self.data.trn_dl), end_lr, linear=linear)
# --> 294         self.fit_gen(self.model, self.data, layer_opt, 1, **kwargs)
#     295         self.load('tmp')
#     296
#
# ~/building-detection-challenge/fastai/learner.py in fit_gen(self, model, data, layer_opt, n_cycle, cycle_len, cycle_mult, cycle_save_name, best_save_name, use_clr, use_clr_beta, metrics, callbacks, use_wd_sched, norm_wds, wds_sched_mult, **kwargs)
#     196         n_epoch = sum_geom(cycle_len if cycle_len else 1, cycle_mult, n_cycle)
#     197         return fit(model, data, n_epoch, layer_opt.opt, self.crit,
# --> 198             metrics=metrics, callbacks=callbacks, reg_fn=self.reg_fn, clip=self.clip, fp16=self.fp16, **kwargs)
#     199
#     200     def get_layer_groups(self): return self.models.get_layer_groups()
#
# ~/building-detection-challenge/fastai/model.py in fit(model, data, epochs, opt, crit, metrics, callbacks, stepper, **kwargs)
#     113             batch_num += 1
#     114             for cb in callbacks: cb.on_batch_begin()
# --> 115             loss = stepper.step(V(x),V(y), epoch)
#     116             avg_loss = avg_loss * avg_mom + loss * (1-avg_mom)
#     117             debias_loss = avg_loss / (1 - avg_mom**batch_num)
#
# ~/building-detection-challenge/fastai/model.py in step(self, xs, y, epoch)
#      45     def step(self, xs, y, epoch):
#      46         xtra = []
# ---> 47         output = self.m(*xs)
#      48         if isinstance(output,tuple): output,*xtra = output
#      49         if self.fp16: self.m.zero_grad()
#
# /home/twofyw/miniconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /home/twofyw/miniconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#      71             return self.module(*inputs[0], **kwargs[0])
#      72         replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
# ---> 73         outputs = self.parallel_apply(replicas, inputs, kwargs)
#      74         return self.gather(outputs, self.output_device)
#      75
#
# /home/twofyw/miniconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/parallel/data_parallel.py in parallel_apply(self, replicas, inputs, kwargs)
#      81
#      82     def parallel_apply(self, replicas, inputs, kwargs):
# ---> 83         return parallel_apply(replicas, inputs, kwargs, self.device_ids[:len(replicas)])
#      84
#      85     def gather(self, outputs, output_device):
#
# /home/twofyw/miniconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/parallel/parallel_apply.py in parallel_apply(modules, inputs, kwargs_tup, devices)
#      65         output = results[i]
#      66         if isinstance(output, Exception):
# ---> 67             raise output
#      68         outputs.append(output)
#      69     return outputs
#
# /home/twofyw/miniconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/parallel/parallel_apply.py in _worker(i, module, input, kwargs, results, lock, device)
#      40         try:
#      41             with torch.cuda.device(device):
# ---> 42                 output = module(*input, **kwargs)
#      43             with lock:
#      44                 results[i] = output
#
# /home/twofyw/miniconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/building-detection-challenge/deeplab/pytorch-deeplab-resnet/deeplab_resnet.py in forward(self, x)
#     196         x2 = self.interp1(x)
#     197         x3 = self.interp2(x)
# --> 198         out.append(self.Scale(x))       # for original scale
#     199         out.append(self.interp3(self.Scale(x2)))        # for 0.75x scale
#     200         out.append(self.Scale(x3))      # for 0.5x scale
#
# /home/twofyw/miniconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/building-detection-challenge/deeplab/pytorch-deeplab-resnet/deeplab_resnet.py in forward(self, x)
#     175         x = self.maxpool(x)
#     176         x = self.layer1(x)
# --> 177         x = self.layer2(x)
#     178         x = self.layer3(x)
#     179         x = self.layer4(x)
#
# /home/twofyw/miniconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /home/twofyw/miniconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# /home/twofyw/miniconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/building-detection-challenge/deeplab/pytorch-deeplab-resnet/deeplab_resnet.py in forward(self, x)
#      91         out = self.relu(out)
#      92
# ---> 93         out = self.conv3(out)
#      94         out = self.bn3(out)
#      95
#
# /home/twofyw/miniconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /home/twofyw/miniconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     280     def forward(self, input):
#     281         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 282                         self.padding, self.dilation, self.groups)
#     283
#     284
#
# /home/twofyw/miniconda3/envs/fastai/lib/python3.6/site-packages/torch/nn/functional.py in conv2d(input, weight, bias, stride, padding, dilation, groups)
#      88                 _pair(0), groups, torch.backends.cudnn.benchmark,
#      89                 torch.backends.cudnn.deterministic, torch.backends.cudnn.enabled)
# ---> 90     return f(input, weight, bias)
#      91
#      92
#
# RuntimeError: cuda runtime error (2) : out of memory at /opt/conda/conda-bld/pytorch_1518244421288/work/torch/lib/THC/generic/THCStorage.cu:58
