# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from learn import *

# %% [markdown]
# Train on full dataset for several epochs

# %%
# %%time
# %run script 1 --gpu_start=0 --num_gpus=3 --bs=80 --lr 1e-4 --num_slice=25 \
    --use_wd_sched --wd 0.025 --n_cycles 3 --model_name unet --learn --start --load_starter ternaus-full
# Out:
# ...
# Data finished loading: data/train/AOI_3_Paris_Train
# ...
# epoch      trn_loss   val_loss   mask_acc   jaccard_coef_par
#     0      0.922493   0.975179   0.939755   0.392683
#     1      0.855204   0.953068   0.939907   0.404226
#     2      0.816777   0.887124   0.948494   0.433169
#     3      0.78457    0.898651   0.939741   0.432168
#     4      0.753125   0.855681   0.947331   0.446939
#     5      0.746844   0.852514   0.9482     0.448387
#     6      0.749499   0.840927   0.948007   0.453237
#     7      0.7432     0.920995   0.933834   0.428567
#  64%|██████▍   | 69/108 [01:43<00:58,  1.50s/it, loss=0.721]    8      0.71726    0.795939   0.950607   0.474813
#     9      0.70462    0.830513   0.946798   0.462001
#     10     0.694441   0.805897   0.950764   0.47218
#     11     0.689444   0.789473   0.954473   0.477648
#     12     0.683269   0.795764   0.952595   0.475866
#     13     0.676747   0.789199   0.95422    0.478046
#
# ...

# %%
train_and_plot(learn, 0, 'ternaus-paris', lrs = lrs, n_cycles=4, wds=wds, use_wd_sched=use_wd_sched,
    cycle_len=1, cycle_mult=2, best_save_name='ternaus-paris')
# Out:
# ...
# epoch      trn_loss   val_loss   mask_acc   jaccard_coef_par
#     0      0.683012   0.761027   0.954796   0.490153
#     1      0.678937   0.747815   0.956882   0.495423
#     2      0.663943   0.749521   0.955947   0.494969
#     3      0.67423    0.763059   0.952638   0.49
#     4      0.671687   0.789585   0.951254   0.48154
#     5      0.654834   0.737141   0.957189   0.501426
#     6      0.645255   0.736477   0.956743   0.502058
#     7      0.664075   0.785958   0.951011   0.483891
#     8      0.65578    0.716492   0.955706   0.510038
#     9      0.63983    0.721992   0.957966   0.509569
#     10     0.646969   0.703918   0.960729   0.512491
#     11     0.631764   0.698198   0.957941   0.519394
#     12     0.625286   0.689677   0.960728   0.521965
#     13     0.629992   0.718995   0.957914   0.511178
#     14     0.626867   0.716169   0.958299   0.512463

# %%
lrs = np.array(lrs) / 10

# %%
train_and_plot(learn, 0, 'ternaus-paris', lrs = lrs, n_cycles=4, wds=wds, use_wd_sched=use_wd_sched,
    cycle_len=1, cycle_mult=2, best_save_name='ternaus-paris')
# Out:
# ...
# epoch      trn_loss   val_loss   mask_acc   jaccard_coef_par
#     0      0.623233   0.715456   0.957944   0.51329
#     1      0.623942   0.722911   0.956707   0.509987
#     2      0.619619   0.717776   0.958007   0.511882
#     3      0.62945    0.714162   0.958666   0.513217
#     4      0.631238   0.713677   0.958455   0.513789
#     5      0.626588   0.715917   0.957758   0.513259
#     6      0.619281   0.712661   0.958717   0.514094
#     7      0.62151    0.747998   0.955558   0.500567
#     8      0.62567    0.715709   0.957739   0.513083
#     9      0.62189    0.710112   0.959184   0.514784
#     10     0.619017   0.713104   0.958647   0.514086
#     11     0.614248   0.713918   0.958449   0.513625
#     12     0.618341   0.712143   0.958827   0.514164
#     13     0.622265   0.710047   0.959112   0.515158
#     14     0.622852   0.710944   0.95885    0.514923

# %%
lr = 1e-6
lrs = np.array([lr / 9, lr])

# %%
train_and_plot(learn, 0, 'ternaus-paris', lrs = lrs, n_cycles=4, wds=wds, use_wd_sched=use_wd_sched,
    cycle_len=1, cycle_mult=2, best_save_name='ternaus-paris')
# Out:
# ...
# epoch      trn_loss   val_loss   mask_acc   jaccard_coef_par
#     0      0.617857   0.70969    0.959068   0.515393
#     1      0.617244   0.709576   0.959248   0.515289
#     2      0.623021   0.710814   0.958887   0.514954
#     3      0.619023   0.710886   0.958993   0.514697
#     4      0.623083   0.712218   0.958439   0.514594
#     5      0.617989   0.713028   0.95834    0.514253
#     6      0.618999   0.712147   0.95854    0.514546
#     7      0.620641   0.712908   0.958338   0.514294
#     8      0.620737   0.711984   0.95835    0.514756
#     9      0.617897   0.711657   0.958531   0.514822
#     10     0.620019   0.710401   0.958949   0.51508
#     11     0.615705   0.710103   0.958953   0.515321
#     12     0.620997   0.710362   0.95894    0.515171
#     13     0.616562   0.710686   0.958821   0.515122
#     14     0.617394   0.710692   0.95882    0.51512

# %%
# %%time
# %run script 1 --gpu_start=0 --num_gpus=3 --bs=80 --lr 1e-5 --num_slice=81 \
    --use_wd_sched --wd 0.025 --n_cycles 3 --model_name unet --learn --start
# Out:
# ...
# Data finished loading: data/train/AOI_3_Paris_Train
# ...
# epoch      trn_loss   val_loss   mask_acc   jaccard_coef_par
#     0      0.669158   1.141379   0.953888   0.378361
#  29%|██▊       | 100/350 [02:00<05:00,  1.20s/it, loss=0.67]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/building-detection-challenge/script.py in <module>()
#     112     if args.start:
#     113         train_and_plot(learn, 0, learn_save_path, lrs = lrs, n_cycles=n_cycles, wds=wds, use_wd_sched=use_wd_sched,
# --> 114             cycle_len=2, cycle_mult=2, best_save_name=learn_save_path)
#     115
#     116
#
# ~/building-detection-challenge/learn.py in train_and_plot(learn, idx, fn, lrs, n_cycles, wds, use_wd_sched, **kwargs)
#     400
#     401 def train_and_plot(learn, idx, fn, lrs, n_cycles, wds=[0.025/3, 0.025], use_wd_sched=False, **kwargs):
# ...

# %%
train_and_plot(learn, 0, 'unet-paris', lrs = lrs, n_cycles=4, wds=wds, use_wd_sched=use_wd_sched,
    cycle_len=1, cycle_mult=2, best_save_name='unet-paris')
# Out:
# ...
# epoch      trn_loss   val_loss   mask_acc   jaccard_coef_par
#     0      0.617041   1.050915   0.958704   0.416978
#     1      0.613668   1.051842   0.958393   0.41675
#     2      0.617029   1.049172   0.958843   0.417855
#     3      0.61783    1.045185   0.959971   0.418691
#     4      0.612451   1.061141   0.958951   0.413066
#     5      0.60746    1.04761    0.959007   0.418732
#     6      0.620959   1.04696    0.958955   0.419146
#     7      0.61347    1.012418   0.960355   0.433076
#     8      0.608686   1.011388   0.961027   0.432788
#     9      0.599404   1.022398   0.959423   0.429659
#     10     0.609198   1.024622   0.960567   0.427842
#     11     0.597553   1.022367   0.959709   0.428977
#     12     0.613071   1.035973   0.959322   0.423865
#     13     0.605333   1.025522   0.960002   0.427997
#     14     0.60064    1.025673   0.959949   0.428003

# %%
lrs = np.array([lr / 9, lr]) / 5

# %%
train_and_plot(learn, 1, 'unet-paris', lrs = lrs, n_cycles=6, wds=wds, use_wd_sched=use_wd_sched,
    cycle_len=1, cycle_mult=2, best_save_name='unet-paris')
# Out:
# ...
# epoch      trn_loss   val_loss   mask_acc   jaccard_coef_par
#     0      0.60836    1.011899   0.960083   0.433486
#     1      0.599577   1.026231   0.959691   0.427911
#     2      0.60459    1.025771   0.959864   0.428058
#     3      0.602357   1.01247    0.960014   0.433348
#     4      0.604266   1.018233   0.960113   0.430933
#     5      0.59887    1.0256     0.959831   0.428186
#  64%|██████▎   | 223/350 [04:15<02:25,  1.15s/it, loss=0.597]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#     12     0.598851   1.010273   0.960183   0.434471
#     13     0.593316   1.018063   0.959896   0.431472
#     14     0.599344   1.017805   0.959944   0.431561
# ...

# %%
train_and_plot(learn, 1, 'unet-paris', lrs = lrs, n_cycles=6, wds=wds, use_wd_sched=use_wd_sched,
    cycle_len=1, cycle_mult=2, best_save_name='unet-paris')
# Out:
# ...
# epoch      trn_loss   val_loss   mask_acc   jaccard_coef_par
#     0      0.581358   0.998351   0.960479   0.440131
#     1      0.580526   1.001363   0.959518   0.439681
#     2      0.590754   0.998142   0.960441   0.440309
#     3      0.587988   0.99877    0.960292   0.44017
#     4      0.586389   0.990524   0.960715   0.443226
#     5      0.587001   0.990416   0.96067    0.443471
#  93%|█████████▎| 326/350 [08:46<00:38,  1.61s/it, loss=0.601]    6      0.597532   0.99069    0.960649   0.443356
#     7      0.589131   0.987075   0.961132   0.444861
#     8      0.594898   0.982146   0.960714   0.447039
#     9      0.586732   0.993493   0.959983   0.442585
#     10     0.59785    0.981665   0.960871   0.447265
#     11     0.5955     0.981906   0.961006   0.446955
#   9%|▉         | 32/350 [00:49<08:11,  1.55s/it, loss=0.592]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# ...

# %%
# %%time
# %run script 1 --gpu_start=0 --num_gpus=1 --bs=32 --lr 1e-5 --num_slice=25 \
    --use_wd_sched --wd 0.025 --n_cycles 4 --model_name unet --learn --start
# Out:
# ...
# Data finished loading: data/train/AOI_3_Paris_Train
# ...
# epoch      trn_loss   val_loss   mask_acc   jaccard_coef_par
#     0      0.59744    0.790768   0.963592   0.512305
#     1      0.595506   0.826274   0.96125    0.49916
#     2      0.583472   0.818039   0.961763   0.501306
#     3      0.579858   0.834546   0.96131    0.495704
#     4      0.580441   0.803346   0.96265    0.507277
#     5      0.58483    0.816753   0.961289   0.502918
#     6      0.59454    0.834643   0.959788   0.496191
#     7      0.592719   0.867961   0.959343   0.482769
#     8      0.58614    0.884349   0.958569   0.475437
#     9      0.593626   0.815745   0.961627   0.502793
#     10     0.591023   0.815606   0.961091   0.503801
#     11     0.584787   0.824469   0.960832   0.500428
#     12     0.57951    0.811905   0.962095   0.504674
#     13     0.585546   0.814082   0.961344   0.504384
#     14     0.592623   0.793517   0.962778   0.511453
#     15     0.592767   0.862371   0.959949   0.485249
# ...

# %%
train_and_plot(learn, 1, 'unet-paris', lrs = lrs, n_cycles=5, wds=wds, use_wd_sched=use_wd_sched,
    cycle_len=1, cycle_mult=2, best_save_name='unet-paris')
